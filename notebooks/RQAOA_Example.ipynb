# %%
import os
# Get the current working directory
current_dir = os.getcwd()
# Get the parent directory
parent_dir = os.path.dirname(current_dir)
# Change the working directory to the parent directory
os.chdir(parent_dir)

# %%
import networkx as nx
from networkx.algorithms import bipartite
from RQAOA import *
from utils import *

# %%
def random_bipartite(n_left, n_right, density, seed, mean=None, std=None):
    # Create bipartite random graph
    G = bipartite.random_graph(n_left, n_right, density, seed=seed)

    if (mean is None) or (std is None):
        nx.set_edge_attributes(G, 1, "weight")
    else:
    
        rng = np.random.default_rng(seed)
        n_edges = G.number_of_edges()
        
        # Draw and re-draw until all are nonzero
        int_weights = np.zeros(n_edges, dtype=int)
        mask = np.ones(n_edges, dtype=bool)
        while np.any(mask):
            new_vals = np.round(rng.normal(loc=mean, scale=std, size=np.sum(mask))).astype(int)
            mask_indices = np.where(mask)[0]
            for i, val in zip(mask_indices, new_vals):
                if val != 0:
                    int_weights[i] = val
                    mask[i] = False  # filled successfully
    
        # Assign weights
        for edge, w in zip(G.edges(), int_weights):
            G.edges[edge]["weight"] = w

    return G

# %%
G = random_bipartite(64, 64, 0.1, 42)

# %%
gm = GraphManager(G, True)
rqaoa_cost, assignments = RQAOA(gm, 120, True)
# Out:
# Iter 0: Graph has 128 nodes and 384 edges remaining.
# QAOA Cost = -238.9057546556537. Anti-Correlating Edge (12, 121) that has maximum absolute weight -0.3622968042167825.
# Node 12 and 121 were contained in 0 and 0 triangles respectively.
# Removing edge (121, 12) with weight 1 from graph.
# Removing node 12 from graph.
# Iter 1: Graph has 127 nodes and 383 edges remaining.
# QAOA Cost = -238.23915221341343. Anti-Correlating Edge (41, 91) that has maximum absolute weight -0.3364690776222753.
# Node 41 and 91 were contained in 0 and 0 triangles respectively.
# Removing edge (91, 41) with weight 1 from graph.
# Removing node 41 from graph.
# Iter 2: Graph has 126 nodes and 382 edges remaining.
# QAOA Cost = -237.59538026494357. Anti-Correlating Edge (53, 106) that has maximum absolute weight -0.33172124999332164.
# Node 53 and 106 were contained in 0 and 0 triangles respectively.
# Removing edge (106, 53) with weight 1 from graph.
# Removing edge (90, 53) with weight 1 from graph.
# Removing edge (127, 53) with weight 1 from graph.
# Removing node 53 from graph.
# Adding edge (90, 106) with weight -1 to graph.
# Adding edge (127, 106) with weight -1 to graph.
# Iter 3: Graph has 125 nodes and 381 edges remaining.
# QAOA Cost = -234.90313432341722. Anti-Correlating Edge (30, 120) that has maximum absolute weight -0.3247564034906806.
# Node 30 and 120 were contained in 0 and 0 triangles respectively.
# Removing edge (120, 30) with weight 1 from graph.
# Removing node 30 from graph.
# Iter 4: Graph has 124 nodes and 380 edges remaining.
# QAOA Cost = -234.268726606769. Anti-Correlating Edge (4, 122) that has maximum absolute weight -0.3202790654315772.
# Node 4 and 122 were contained in 0 and 0 triangles respectively.
# Removing edge (122, 4) with weight 1 from graph.
# Removing edge (66, 4) with weight 1 from graph.
# Removing edge (74, 4) with weight 1 from graph.
# Removing edge (109, 4) with weight 1 from graph.
# Removing edge (114, 4) with weight 1 from graph.
# Removing node 4 from graph.
# Adding edge (66, 122) with weight -1 to graph.
# Adding edge (74, 122) with weight -1 to graph.
# Adding edge (109, 122) with weight -1 to graph.
# Adding edge (114, 122) with weight -1 to graph.
# Iter 5: Graph has 123 nodes and 379 edges remaining.
# QAOA Cost = -229.58885638997359. Anti-Correlating Edge (33, 110) that has maximum absolute weight -0.3200118366037895.
# Node 33 and 110 were contained in 0 and 0 triangles respectively.
# Removing edge (110, 33) with weight 1 from graph.
# Removing edge (86, 33) with weight 1 from graph.
# Removing edge (89, 33) with weight 1 from graph.
# Removing edge (104, 33) with weight 1 from graph.
# Removing edge (116, 33) with weight 1 from graph.
# Removing node 33 from graph.
# Adding edge (86, 110) with weight -1 to graph.
# Adding edge (89, 110) with weight -1 to graph.
# Adding edge (104, 110) with weight -1 to graph.
# Adding edge (116, 110) with weight -1 to graph.
# Iter 6: Graph has 122 nodes and 378 edges remaining.
# QAOA Cost = -224.90919760739038. Anti-Correlating Edge (50, 118) that has maximum absolute weight -0.31758133692924584.
# Node 50 and 118 were contained in 0 and 0 triangles respectively.
# Removing edge (118, 50) with weight 1 from graph.
# Removing edge (83, 50) with weight 1 from graph.
# Removing edge (99, 50) with weight 1 from graph.
# Removing node 50 from graph.
# Adding edge (83, 118) with weight -1 to graph.
# Adding edge (99, 118) with weight -1 to graph.
# Iter 7: Graph has 121 nodes and 377 edges remaining.
# QAOA Cost = -222.32727816563806. Anti-Correlating Edge (8, 118) that has maximum absolute weight -0.3427096051940662.
# Node 8 and 118 were contained in 1 and 2 triangles respectively.
# Removing edge (118, 8) with weight 1 from graph.
# Removing edge (89, 8) with weight 1 from graph.
# Removing edge (99, 8) with weight 1 from graph.
# Removing edge (107, 8) with weight 1 from graph.
# Removing node 8 from graph.
# Adding edge (89, 118) with weight -1 to graph.
# Adding edge (99, 118) with weight -2 to graph.
# Adding edge (107, 118) with weight -1 to graph.
# Iter 8: Graph has 120 nodes and 375 edges remaining.
# QAOA Cost = -218.68616090599377. Correlating Edge (99, 118) that has maximum absolute weight 0.47338240929406555.
# Node 99 and 118 were contained in 1 and 1 triangles respectively.
# Removing edge (118, 99) with weight -2 from graph.
# Removing edge (6, 99) with weight 1 from graph.
# Removing edge (13, 99) with weight 1 from graph.
# Removing edge (38, 99) with weight 1 from graph.
# Removing edge (47, 99) with weight 1 from graph.
# Removing edge (51, 99) with weight 1 from graph.
# Removing edge (52, 99) with weight 1 from graph.
# Removing edge (63, 99) with weight 1 from graph.
# Removing node 99 from graph.
# Adding edge (6, 118) with weight 1 to graph.
# Adding edge (13, 118) with weight 1 to graph.
# Adding edge (38, 118) with weight 1 to graph.
# Adding edge (47, 118) with weight 1 to graph.
# Adding edge (51, 118) with weight 1 to graph.
# Adding edge (52, 118) with weight 2 to graph.
# Adding edge (63, 118) with weight 1 to graph.
# Iter 9: Graph has 119 nodes and 373 edges remaining.
# QAOA Cost = -219.23235525820795. Anti-Correlating Edge (52, 118) that has maximum absolute weight -0.4619564332520224.
# Node 52 and 118 were contained in 0 and 1 triangles respectively.
# Removing edge (118, 52) with weight 2 from graph.
# Removing edge (71, 52) with weight 1 from graph.
# Removing edge (73, 52) with weight 1 from graph.
# Removing node 52 from graph.
# Adding edge (71, 118) with weight -1 to graph.
# Adding edge (73, 118) with weight -1 to graph.
# Iter 10: Graph has 118 nodes and 372 edges remaining.
# QAOA Cost = -215.85805868091435. Anti-Correlating Edge (34, 82) that has maximum absolute weight -0.3121532661090237.
# Node 34 and 82 were contained in 0 and 0 triangles respectively.
# Removing edge (82, 34) with weight 1 from graph.
# Removing node 34 from graph.
# Iter 11: Graph has 117 nodes and 371 edges remaining.
# QAOA Cost = -215.2320380663255. Anti-Correlating Edge (14, 94) that has maximum absolute weight -0.30711755002147345.
# Node 14 and 94 were contained in 0 and 0 triangles respectively.
# Removing edge (94, 14) with weight 1 from graph.
# Removing edge (102, 14) with weight 1 from graph.
# Removing node 14 from graph.
# Adding edge (102, 94) with weight -1 to graph.
# Iter 12: Graph has 116 nodes and 370 edges remaining.
# QAOA Cost = -213.6473557268265. Correlating Edge (94, 102) that has maximum absolute weight 0.3202454752985613.
# Node 94 and 102 were contained in 2 and 2 triangles respectively.
# Removing edge (102, 94) with weight -1 from graph.
# Removing edge (0, 94) with weight 1 from graph.
# Removing edge (6, 94) with weight 1 from graph.
# Removing edge (39, 94) with weight 1 from graph.
# Removing edge (48, 94) with weight 1 from graph.
# Removing edge (55, 94) with weight 1 from graph.
# Removing node 94 from graph.
# Adding edge (0, 102) with weight 1 to graph.
# Adding edge (6, 102) with weight 2 to graph.
# Adding edge (39, 102) with weight 1 to graph.
# Adding edge (48, 102) with weight 2 to graph.
# Adding edge (55, 102) with weight 1 to graph.
# Iter 13: Graph has 115 nodes and 367 edges remaining.
# QAOA Cost = -213.81063422236258. Anti-Correlating Edge (48, 102) that has maximum absolute weight -0.3640929496414884.
# Node 48 and 102 were contained in 0 and 0 triangles respectively.
# Removing edge (102, 48) with weight 2 from graph.
# Removing edge (70, 48) with weight 1 from graph.
# Removing edge (73, 48) with weight 1 from graph.
# Removing edge (86, 48) with weight 1 from graph.
# Removing edge (100, 48) with weight 1 from graph.
# Removing edge (101, 48) with weight 1 from graph.
# Removing edge (123, 48) with weight 1 from graph.
# Removing node 48 from graph.
# Adding edge (70, 102) with weight -1 to graph.
# Adding edge (73, 102) with weight -1 to graph.
# Adding edge (86, 102) with weight -1 to graph.
# Adding edge (100, 102) with weight -1 to graph.
# Adding edge (101, 102) with weight -1 to graph.
# Adding edge (123, 102) with weight -1 to graph.
# Iter 14: Graph has 114 nodes and 366 edges remaining.
# QAOA Cost = -206.4535157956456. Anti-Correlating Edge (6, 102) that has maximum absolute weight -0.331041620532015.
# Node 6 and 102 were contained in 4 and 4 triangles respectively.
# Removing edge (102, 6) with weight 2 from graph.
# Removing edge (65, 6) with weight 1 from graph.
# Removing edge (69, 6) with weight 1 from graph.
# Removing edge (70, 6) with weight 1 from graph.
# Removing edge (73, 6) with weight 1 from graph.
# Removing edge (75, 6) with weight 1 from graph.
# Removing edge (79, 6) with weight 1 from graph.
# Removing edge (89, 6) with weight 1 from graph.
# Removing edge (105, 6) with weight 1 from graph.
# Removing edge (118, 6) with weight 1 from graph.
# Removing node 6 from graph.
# Adding edge (65, 102) with weight -1 to graph.
# Adding edge (69, 102) with weight -1 to graph.
# Adding edge (70, 102) with weight -2 to graph.
# Adding edge (73, 102) with weight -2 to graph.
# Adding edge (75, 102) with weight -1 to graph.
# Adding edge (79, 102) with weight -1 to graph.
# Adding edge (89, 102) with weight -1 to graph.
# Adding edge (105, 102) with weight -1 to graph.
# Adding edge (118, 102) with weight -1 to graph.
# Iter 15: Graph has 113 nodes and 363 edges remaining.
# QAOA Cost = -195.91455679920531. Anti-Correlating Edge (37, 69) that has maximum absolute weight -0.3273221121501543.
# Node 37 and 69 were contained in 2 and 1 triangles respectively.
# Removing edge (69, 37) with weight 1 from graph.
# Removing edge (71, 37) with weight 1 from graph.
# Removing edge (102, 37) with weight 1 from graph.
# Removing edge (103, 37) with weight 1 from graph.
# Removing edge (105, 37) with weight 1 from graph.
# Removing edge (114, 37) with weight 1 from graph.
# Removing edge (125, 37) with weight 1 from graph.
# Removing node 37 from graph.
# Adding edge (71, 69) with weight -1 to graph.
# Adding edge (102, 69) with weight -2 to graph.
# Adding edge (103, 69) with weight -1 to graph.
# Adding edge (105, 69) with weight -1 to graph.
# Adding edge (114, 69) with weight -1 to graph.
# Adding edge (125, 69) with weight -1 to graph.
# Iter 16: Graph has 112 nodes and 361 edges remaining.
# QAOA Cost = -188.9946855657696. Anti-Correlating Edge (31, 107) that has maximum absolute weight -0.2958359741653542.
# Node 31 and 107 were contained in 0 and 0 triangles respectively.
# Removing edge (107, 31) with weight 1 from graph.
# Removing edge (74, 31) with weight 1 from graph.
# Removing node 31 from graph.
# Adding edge (74, 107) with weight -1 to graph.
# Iter 17: Graph has 111 nodes and 360 edges remaining.
# QAOA Cost = -187.52368568729455. Anti-Correlating Edge (23, 119) that has maximum absolute weight -0.30007814338576894.
# Node 23 and 119 were contained in 0 and 0 triangles respectively.
# Removing edge (119, 23) with weight 1 from graph.
# Removing edge (103, 23) with weight 1 from graph.
# Removing edge (113, 23) with weight 1 from graph.
# Removing edge (126, 23) with weight 1 from graph.
# Removing node 23 from graph.
# Adding edge (103, 119) with weight -1 to graph.
# Adding edge (113, 119) with weight -1 to graph.
# Adding edge (126, 119) with weight -1 to graph.
# Iter 18: Graph has 110 nodes and 359 edges remaining.
# QAOA Cost = -183.80952405438333. Anti-Correlating Edge (2, 100) that has maximum absolute weight -0.29573526346669654.
# Node 2 and 100 were contained in 1 and 1 triangles respectively.
# Removing edge (100, 2) with weight 1 from graph.
# Removing edge (67, 2) with weight 1 from graph.
# Removing edge (68, 2) with weight 1 from graph.
# Removing edge (84, 2) with weight 1 from graph.
# Removing edge (96, 2) with weight 1 from graph.
# Removing edge (102, 2) with weight 1 from graph.
# Removing node 2 from graph.
# Adding edge (67, 100) with weight -1 to graph.
# Adding edge (68, 100) with weight -1 to graph.
# Adding edge (84, 100) with weight -1 to graph.
# Adding edge (96, 100) with weight -1 to graph.
# Adding edge (102, 100) with weight -2 to graph.
# Iter 19: Graph has 109 nodes and 357 edges remaining.
# QAOA Cost = -178.05136193514403. Anti-Correlating Edge (49, 108) that has maximum absolute weight -0.2928380515465295.
# Node 49 and 108 were contained in 0 and 0 triangles respectively.
# Removing edge (108, 49) with weight 1 from graph.
# Removing edge (82, 49) with weight 1 from graph.
# Removing edge (90, 49) with weight 1 from graph.
# Removing edge (117, 49) with weight 1 from graph.
# Removing edge (119, 49) with weight 1 from graph.
# Removing edge (121, 49) with weight 1 from graph.
# Removing edge (125, 49) with weight 1 from graph.
# Removing node 49 from graph.
# Adding edge (82, 108) with weight -1 to graph.
# Adding edge (90, 108) with weight -1 to graph.
# Adding edge (117, 108) with weight -1 to graph.
# Adding edge (119, 108) with weight -1 to graph.
# Adding edge (121, 108) with weight -1 to graph.
# Adding edge (125, 108) with weight -1 to graph.
# Iter 20: Graph has 108 nodes and 356 edges remaining.
# QAOA Cost = -171.37764030440374. Correlating Edge (108, 121) that has maximum absolute weight 0.29259871032900725.
# Node 108 and 121 were contained in 0 and 0 triangles respectively.
# Removing edge (121, 108) with weight -1 from graph.
# Removing edge (26, 108) with weight 1 from graph.
# Removing edge (82, 108) with weight -1 from graph.
# Removing edge (90, 108) with weight -1 from graph.
# Removing edge (117, 108) with weight -1 from graph.
# Removing edge (119, 108) with weight -1 from graph.
# Removing edge (125, 108) with weight -1 from graph.
# Removing node 108 from graph.
# Adding edge (26, 121) with weight 1 to graph.
# Adding edge (82, 121) with weight -1 to graph.
# Adding edge (90, 121) with weight -1 to graph.
# Adding edge (117, 121) with weight -1 to graph.
# Adding edge (119, 121) with weight -1 to graph.
# Adding edge (125, 121) with weight -1 to graph.
# Iter 21: Graph has 107 nodes and 355 edges remaining.
# QAOA Cost = -171.70415450341855. Anti-Correlating Edge (27, 79) that has maximum absolute weight -0.2890896693868879.
# Node 27 and 79 were contained in 0 and 0 triangles respectively.
# Removing edge (79, 27) with weight 1 from graph.
# Removing edge (66, 27) with weight 1 from graph.
# Removing edge (90, 27) with weight 1 from graph.
# Removing node 27 from graph.
# Adding edge (66, 79) with weight -1 to graph.
# Adding edge (90, 79) with weight -1 to graph.
# Iter 22: Graph has 106 nodes and 354 edges remaining.
# QAOA Cost = -169.04460095443463. Anti-Correlating Edge (29, 106) that has maximum absolute weight -0.28716922825909835.
# Node 29 and 106 were contained in 0 and 0 triangles respectively.
# Removing edge (106, 29) with weight 1 from graph.
# Removing edge (81, 29) with weight 1 from graph.
# Removing edge (87, 29) with weight 1 from graph.
# Removing edge (114, 29) with weight 1 from graph.
# Removing edge (115, 29) with weight 1 from graph.
# Removing node 29 from graph.
# Adding edge (81, 106) with weight -1 to graph.
# Adding edge (87, 106) with weight -1 to graph.
# Adding edge (114, 106) with weight -1 to graph.
# Adding edge (115, 106) with weight -1 to graph.
# Iter 23: Graph has 105 nodes and 353 edges remaining.
# QAOA Cost = -164.40048675463123. Anti-Correlating Edge (35, 91) that has maximum absolute weight -0.2867932829335922.
# Node 35 and 91 were contained in 0 and 0 triangles respectively.
# Removing edge (91, 35) with weight 1 from graph.
# Removing edge (70, 35) with weight 1 from graph.
# Removing edge (78, 35) with weight 1 from graph.
# Removing edge (93, 35) with weight 1 from graph.
# Removing edge (97, 35) with weight 1 from graph.
# Removing node 35 from graph.
# Adding edge (70, 91) with weight -1 to graph.
# Adding edge (78, 91) with weight -1 to graph.
# Adding edge (93, 91) with weight -1 to graph.
# Adding edge (97, 91) with weight -1 to graph.
# Iter 24: Graph has 104 nodes and 352 edges remaining.
# QAOA Cost = -159.7198098914114. Anti-Correlating Edge (43, 91) that has maximum absolute weight -0.29532974209021.
# Node 43 and 91 were contained in 1 and 1 triangles respectively.
# Removing edge (91, 43) with weight 1 from graph.
# Removing edge (70, 43) with weight 1 from graph.
# Removing edge (96, 43) with weight 1 from graph.
# Removing edge (98, 43) with weight 1 from graph.
# Removing edge (116, 43) with weight 1 from graph.
# Removing node 43 from graph.
# Adding edge (70, 91) with weight -2 to graph.
# Adding edge (96, 91) with weight -1 to graph.
# Adding edge (98, 91) with weight -1 to graph.
# Adding edge (116, 91) with weight -1 to graph.
# Iter 25: Graph has 103 nodes and 350 edges remaining.
# QAOA Cost = -155.02309723103934. Correlating Edge (70, 91) that has maximum absolute weight 0.3646304087282687.
# Node 70 and 91 were contained in 0 and 2 triangles respectively.
# Removing edge (91, 70) with weight -2 from graph.
# Removing edge (1, 70) with weight 1 from graph.
# Removing edge (26, 70) with weight 1 from graph.
# Removing edge (56, 70) with weight 1 from graph.
# Removing edge (58, 70) with weight 1 from graph.
# Removing edge (60, 70) with weight 1 from graph.
# Removing edge (102, 70) with weight -2 from graph.
# Removing node 70 from graph.
# Adding edge (1, 91) with weight 1 to graph.
# Adding edge (26, 91) with weight 1 to graph.
# Adding edge (56, 91) with weight 1 to graph.
# Adding edge (58, 91) with weight 1 to graph.
# Adding edge (60, 91) with weight 1 to graph.
# Adding edge (102, 91) with weight -2 to graph.
# Iter 26: Graph has 102 nodes and 349 edges remaining.
# QAOA Cost = -155.46338679995992. Anti-Correlating Edge (15, 116) that has maximum absolute weight -0.2946974670186945.
# Node 15 and 116 were contained in 1 and 1 triangles respectively.
# Removing edge (116, 15) with weight 1 from graph.
# Removing edge (72, 15) with weight 1 from graph.
# Removing edge (91, 15) with weight 1 from graph.
# Removing edge (92, 15) with weight 1 from graph.
# Removing edge (105, 15) with weight 1 from graph.
# Removing edge (124, 15) with weight 1 from graph.
# Removing edge (127, 15) with weight 1 from graph.
# Removing node 15 from graph.
# Adding edge (72, 116) with weight -1 to graph.
# Adding edge (91, 116) with weight -2 to graph.
# Adding edge (92, 116) with weight -1 to graph.
# Adding edge (105, 116) with weight -1 to graph.
# Adding edge (124, 116) with weight -1 to graph.
# Adding edge (127, 116) with weight -1 to graph.
# Iter 27: Graph has 101 nodes and 347 edges remaining.
# QAOA Cost = -148.6683186017693. Correlating Edge (91, 116) that has maximum absolute weight 0.30518968581145145.
# Node 91 and 116 were contained in 1 and 0 triangles respectively.
# Removing edge (116, 91) with weight -2 from graph.
# Removing edge (9, 91) with weight 1 from graph.
# Removing edge (78, 91) with weight -1 from graph.
# Removing edge (93, 91) with weight -1 from graph.
# Removing edge (97, 91) with weight -1 from graph.
# Removing edge (96, 91) with weight -1 from graph.
# Removing edge (98, 91) with weight -1 from graph.
# Removing edge (1, 91) with weight 1 from graph.
# Removing edge (26, 91) with weight 1 from graph.
# Removing edge (56, 91) with weight 1 from graph.
# Removing edge (58, 91) with weight 1 from graph.
# Removing edge (60, 91) with weight 1 from graph.
# Removing edge (102, 91) with weight -2 from graph.
# Removing node 91 from graph.
# Adding edge (9, 116) with weight 1 to graph.
# Adding edge (78, 116) with weight -1 to graph.
# Adding edge (93, 116) with weight -1 to graph.
# Adding edge (97, 116) with weight -1 to graph.
# Adding edge (96, 116) with weight -1 to graph.
# Adding edge (98, 116) with weight -1 to graph.
# Adding edge (1, 116) with weight 1 to graph.
# Adding edge (26, 116) with weight 1 to graph.
# Adding edge (56, 116) with weight 1 to graph.
# Adding edge (58, 116) with weight 1 to graph.
# Adding edge (60, 116) with weight 1 to graph.
# Adding edge (102, 116) with weight -2 to graph.
# Iter 28: Graph has 100 nodes and 346 edges remaining.
# QAOA Cost = -149.31904052274263. Anti-Correlating Edge (56, 92) that has maximum absolute weight -0.3191352195152605.
# Node 56 and 92 were contained in 1 and 2 triangles respectively.
# Removing edge (92, 56) with weight 1 from graph.
# Removing edge (89, 56) with weight 1 from graph.
# Removing edge (109, 56) with weight 1 from graph.
# Removing edge (115, 56) with weight 1 from graph.
# Removing edge (119, 56) with weight 1 from graph.
# Removing edge (116, 56) with weight 1 from graph.
# Removing node 56 from graph.
# Adding edge (89, 92) with weight -1 to graph.
# Adding edge (109, 92) with weight -1 to graph.
# Adding edge (115, 92) with weight -1 to graph.
# Adding edge (119, 92) with weight -1 to graph.
# Adding edge (116, 92) with weight -2 to graph.
# Iter 29: Graph has 99 nodes and 344 edges remaining.
# QAOA Cost = -143.59358422558458. Correlating Edge (92, 116) that has maximum absolute weight 0.30742729798149027.
# Node 92 and 116 were contained in 1 and 8 triangles respectively.
# Removing edge (116, 92) with weight -2 from graph.
# Removing edge (3, 92) with weight 1 from graph.
# Removing edge (26, 92) with weight 1 from graph.
# Removing edge (89, 92) with weight -1 from graph.
# Removing edge (109, 92) with weight -1 from graph.
# Removing edge (115, 92) with weight -1 from graph.
# Removing edge (119, 92) with weight -1 from graph.
# Removing node 92 from graph.
# Adding edge (3, 116) with weight 1 to graph.
# Adding edge (26, 116) with weight 2 to graph.
# Adding edge (89, 116) with weight -1 to graph.
# Adding edge (109, 116) with weight -1 to graph.
# Adding edge (115, 116) with weight -1 to graph.
# Adding edge (119, 116) with weight -1 to graph.
# Iter 30: Graph has 98 nodes and 342 edges remaining.
# QAOA Cost = -144.222274665069. Anti-Correlating Edge (22, 96) that has maximum absolute weight -0.2935271217615161.
# Node 22 and 96 were contained in 2 and 1 triangles respectively.
# Removing edge (96, 22) with weight 1 from graph.
# Removing edge (79, 22) with weight 1 from graph.
# Removing edge (85, 22) with weight 1 from graph.
# Removing edge (88, 22) with weight 1 from graph.
# Removing edge (109, 22) with weight 1 from graph.
# Removing edge (112, 22) with weight 1 from graph.
# Removing edge (116, 22) with weight 1 from graph.
# Removing node 22 from graph.
# Adding edge (79, 96) with weight -1 to graph.
# Adding edge (85, 96) with weight -1 to graph.
# Adding edge (88, 96) with weight -1 to graph.
# Adding edge (109, 96) with weight -1 to graph.
# Adding edge (112, 96) with weight -1 to graph.
# Adding edge (116, 96) with weight -2 to graph.
# Iter 31: Graph has 97 nodes and 340 edges remaining.
# QAOA Cost = -137.5014387195189. Anti-Correlating Edge (58, 127) that has maximum absolute weight -0.29289551563476085.
# Node 58 and 127 were contained in 2 and 1 triangles respectively.
# Removing edge (127, 58) with weight 1 from graph.
# Removing edge (74, 58) with weight 1 from graph.
# Removing edge (84, 58) with weight 1 from graph.
# Removing edge (89, 58) with weight 1 from graph.
# Removing edge (116, 58) with weight 1 from graph.
# Removing node 58 from graph.
# Adding edge (74, 127) with weight -1 to graph.
# Adding edge (84, 127) with weight -1 to graph.
# Adding edge (89, 127) with weight -1 to graph.
# Adding edge (116, 127) with weight -2 to graph.
# Iter 32: Graph has 96 nodes and 338 edges remaining.
# QAOA Cost = -132.78071054874755. Anti-Correlating Edge (60, 115) that has maximum absolute weight -0.2916479959189488.
# Node 60 and 115 were contained in 3 and 3 triangles respectively.
# Removing edge (115, 60) with weight 1 from graph.
# Removing edge (72, 60) with weight 1 from graph.
# Removing edge (104, 60) with weight 1 from graph.
# Removing edge (107, 60) with weight 1 from graph.
# Removing edge (109, 60) with weight 1 from graph.
# Removing edge (116, 60) with weight 1 from graph.
# Removing node 60 from graph.
# Adding edge (72, 115) with weight -1 to graph.
# Adding edge (104, 115) with weight -1 to graph.
# Adding edge (107, 115) with weight -1 to graph.
# Adding edge (109, 115) with weight -1 to graph.
# Adding edge (116, 115) with weight -2 to graph.
# Iter 33: Graph has 95 nodes and 336 edges remaining.
# QAOA Cost = -127.03861753303684. Correlating Edge (69, 102) that has maximum absolute weight 0.28387057404317717.
# Node 69 and 102 were contained in 1 and 8 triangles respectively.
# Removing edge (102, 69) with weight -2 from graph.
# Removing edge (18, 69) with weight 1 from graph.
# Removing edge (71, 69) with weight -1 from graph.
# Removing edge (103, 69) with weight -1 from graph.
# Removing edge (105, 69) with weight -1 from graph.
# Removing edge (114, 69) with weight -1 from graph.
# Removing edge (125, 69) with weight -1 from graph.
# Removing node 69 from graph.
# Adding edge (18, 102) with weight 1 to graph.
# Adding edge (71, 102) with weight -1 to graph.
# Adding edge (103, 102) with weight -1 to graph.
# Adding edge (105, 102) with weight -2 to graph.
# Adding edge (114, 102) with weight -1 to graph.
# Adding edge (125, 102) with weight -1 to graph.
# Iter 34: Graph has 94 nodes and 334 edges remaining.
# QAOA Cost = -127.60283477280257. Anti-Correlating Edge (55, 114) that has maximum absolute weight -0.291414220128052.
# Node 55 and 114 were contained in 1 and 1 triangles respectively.
# Removing edge (114, 55) with weight 1 from graph.
# Removing edge (78, 55) with weight 1 from graph.
# Removing edge (97, 55) with weight 1 from graph.
# Removing edge (112, 55) with weight 1 from graph.
# Removing edge (102, 55) with weight 1 from graph.
# Removing node 55 from graph.
# Adding edge (78, 114) with weight -1 to graph.
# Adding edge (97, 114) with weight -1 to graph.
# Adding edge (112, 114) with weight -1 to graph.
# Adding edge (102, 114) with weight -2 to graph.
# Iter 35: Graph has 93 nodes and 332 edges remaining.
# QAOA Cost = -122.85619380604126. Anti-Correlating Edge (18, 79) that has maximum absolute weight -0.2903988051179952.
# Node 18 and 79 were contained in 3 and 3 triangles respectively.
# Removing edge (79, 18) with weight 1 from graph.
# Removing edge (65, 18) with weight 1 from graph.
# Removing edge (88, 18) with weight 1 from graph.
# Removing edge (90, 18) with weight 1 from graph.
# Removing edge (104, 18) with weight 1 from graph.
# Removing edge (112, 18) with weight 1 from graph.
# Removing edge (127, 18) with weight 1 from graph.
# Removing edge (102, 18) with weight 1 from graph.
# Removing node 18 from graph.
# Adding edge (65, 79) with weight -1 to graph.
# Adding edge (88, 79) with weight -1 to graph.
# Adding edge (90, 79) with weight -2 to graph.
# Adding edge (104, 79) with weight -1 to graph.
# Adding edge (112, 79) with weight -1 to graph.
# Adding edge (127, 79) with weight -1 to graph.
# Adding edge (102, 79) with weight -2 to graph.
# Iter 36: Graph has 92 nodes and 329 edges remaining.
# QAOA Cost = -115.07767360240906. Correlating Edge (79, 90) that has maximum absolute weight 0.39023631199219294.
# Node 79 and 90 were contained in 4 and 0 triangles respectively.
# Removing edge (90, 79) with weight -2 from graph.
# Removing edge (25, 79) with weight 1 from graph.
# Removing edge (51, 79) with weight 1 from graph.
# Removing edge (102, 79) with weight -2 from graph.
# Removing edge (66, 79) with weight -1 from graph.
# Removing edge (96, 79) with weight -1 from graph.
# Removing edge (65, 79) with weight -1 from graph.
# Removing edge (88, 79) with weight -1 from graph.
# Removing edge (104, 79) with weight -1 from graph.
# Removing edge (112, 79) with weight -1 from graph.
# Removing edge (127, 79) with weight -1 from graph.
# Removing node 79 from graph.
# Adding edge (25, 90) with weight 1 to graph.
# Adding edge (51, 90) with weight 1 to graph.
# Adding edge (102, 90) with weight -2 to graph.
# Adding edge (66, 90) with weight -1 to graph.
# Adding edge (96, 90) with weight -1 to graph.
# Adding edge (65, 90) with weight -1 to graph.
# Adding edge (88, 90) with weight -1 to graph.
# Adding edge (104, 90) with weight -1 to graph.
# Adding edge (112, 90) with weight -1 to graph.
# Adding edge (127, 90) with weight -1 to graph.
# Iter 37: Graph has 91 nodes and 328 edges remaining.
# QAOA Cost = -115.65845846014842. Anti-Correlating Edge (36, 97) that has maximum absolute weight -0.27866255603819695.
# Node 36 and 97 were contained in 1 and 1 triangles respectively.
# Removing edge (97, 36) with weight 1 from graph.
# Removing edge (66, 36) with weight 1 from graph.
# Removing edge (75, 36) with weight 1 from graph.
# Removing edge (83, 36) with weight 1 from graph.
# Removing edge (98, 36) with weight 1 from graph.
# Removing edge (107, 36) with weight 1 from graph.
# Removing edge (114, 36) with weight 1 from graph.
# Removing node 36 from graph.
# Adding edge (66, 97) with weight -1 to graph.
# Adding edge (75, 97) with weight -1 to graph.
# Adding edge (83, 97) with weight -1 to graph.
# Adding edge (98, 97) with weight -1 to graph.
# Adding edge (107, 97) with weight -1 to graph.
# Adding edge (114, 97) with weight -2 to graph.
# Iter 38: Graph has 90 nodes and 326 edges remaining.
# QAOA Cost = -108.93867673357197. Correlating Edge (97, 114) that has maximum absolute weight 0.3521451762708386.
# Node 97 and 114 were contained in 2 and 0 triangles respectively.
# Removing edge (114, 97) with weight -2 from graph.
# Removing edge (11, 97) with weight 1 from graph.
# Removing edge (24, 97) with weight 1 from graph.
# Removing edge (39, 97) with weight 1 from graph.
# Removing edge (116, 97) with weight -1 from graph.
# Removing edge (66, 97) with weight -1 from graph.
# Removing edge (75, 97) with weight -1 from graph.
# Removing edge (83, 97) with weight -1 from graph.
# Removing edge (98, 97) with weight -1 from graph.
# Removing edge (107, 97) with weight -1 from graph.
# Removing node 97 from graph.
# Adding edge (11, 114) with weight 1 to graph.
# Adding edge (24, 114) with weight 1 to graph.
# Adding edge (39, 114) with weight 1 to graph.
# Adding edge (116, 114) with weight -1 to graph.
# Adding edge (66, 114) with weight -1 to graph.
# Adding edge (75, 114) with weight -1 to graph.
# Adding edge (83, 114) with weight -1 to graph.
# Adding edge (98, 114) with weight -1 to graph.
# Adding edge (107, 114) with weight -1 to graph.
# Iter 39: Graph has 89 nodes and 325 edges remaining.
# QAOA Cost = -109.55968589430425. Correlating Edge (66, 122) that has maximum absolute weight 0.28783949129970676.
# Node 66 and 122 were contained in 2 and 1 triangles respectively.
# Removing edge (122, 66) with weight -1 from graph.
# Removing edge (13, 66) with weight 1 from graph.
# Removing edge (21, 66) with weight 1 from graph.
# Removing edge (28, 66) with weight 1 from graph.
# Removing edge (38, 66) with weight 1 from graph.
# Removing edge (90, 66) with weight -1 from graph.
# Removing edge (114, 66) with weight -1 from graph.
# Removing node 66 from graph.
# Adding edge (13, 122) with weight 1 to graph.
# Adding edge (21, 122) with weight 1 to graph.
# Adding edge (28, 122) with weight 1 to graph.
# Adding edge (38, 122) with weight 1 to graph.
# Adding edge (90, 122) with weight -1 to graph.
# Adding edge (114, 122) with weight -2 to graph.
# Iter 40: Graph has 88 nodes and 323 edges remaining.
# QAOA Cost = -109.84744175120223. Correlating Edge (114, 122) that has maximum absolute weight 0.3064427410521868.
# Node 114 and 122 were contained in 9 and 3 triangles respectively.
# Removing edge (122, 114) with weight -2 from graph.
# Removing edge (46, 114) with weight 1 from graph.
# Removing edge (61, 114) with weight 1 from graph.
# Removing edge (106, 114) with weight -1 from graph.
# Removing edge (102, 114) with weight -2 from graph.
# Removing edge (78, 114) with weight -1 from graph.
# Removing edge (112, 114) with weight -1 from graph.
# Removing edge (11, 114) with weight 1 from graph.
# Removing edge (24, 114) with weight 1 from graph.
# Removing edge (39, 114) with weight 1 from graph.
# Removing edge (116, 114) with weight -1 from graph.
# Removing edge (75, 114) with weight -1 from graph.
# Removing edge (83, 114) with weight -1 from graph.
# Removing edge (98, 114) with weight -1 from graph.
# Removing edge (107, 114) with weight -1 from graph.
# Removing node 114 from graph.
# Adding edge (46, 122) with weight 1 to graph.
# Adding edge (61, 122) with weight 1 to graph.
# Adding edge (106, 122) with weight -1 to graph.
# Adding edge (102, 122) with weight -2 to graph.
# Adding edge (78, 122) with weight -1 to graph.
# Adding edge (112, 122) with weight -1 to graph.
# Adding edge (11, 122) with weight 1 to graph.
# Adding edge (24, 122) with weight 1 to graph.
# Adding edge (39, 122) with weight 1 to graph.
# Adding edge (116, 122) with weight -1 to graph.
# Adding edge (75, 122) with weight -1 to graph.
# Adding edge (83, 122) with weight -1 to graph.
# Adding edge (98, 122) with weight -1 to graph.
# Adding edge (107, 122) with weight -1 to graph.
# Iter 41: Graph has 87 nodes and 322 edges remaining.
# QAOA Cost = -110.46758199840625. Anti-Correlating Edge (39, 112) that has maximum absolute weight -0.27639239075524635.
# Node 39 and 112 were contained in 3 and 4 triangles respectively.
# Removing edge (112, 39) with weight 1 from graph.
# Removing edge (68, 39) with weight 1 from graph.
# Removing edge (109, 39) with weight 1 from graph.
# Removing edge (117, 39) with weight 1 from graph.
# Removing edge (102, 39) with weight 1 from graph.
# Removing edge (122, 39) with weight 1 from graph.
# Removing node 39 from graph.
# Adding edge (68, 112) with weight -1 to graph.
# Adding edge (109, 112) with weight -1 to graph.
# Adding edge (117, 112) with weight -1 to graph.
# Adding edge (102, 112) with weight -1 to graph.
# Adding edge (122, 112) with weight -2 to graph.
# Iter 42: Graph has 86 nodes and 320 edges remaining.
# QAOA Cost = -104.76000524759961. Correlating Edge (112, 122) that has maximum absolute weight 0.31676669245838124.
# Node 112 and 122 were contained in 7 and 23 triangles respectively.
# Removing edge (122, 112) with weight -2 from graph.
# Removing edge (21, 112) with weight 1 from graph.
# Removing edge (26, 112) with weight 1 from graph.
# Removing edge (63, 112) with weight 1 from graph.
# Removing edge (96, 112) with weight -1 from graph.
# Removing edge (90, 112) with weight -1 from graph.
# Removing edge (68, 112) with weight -1 from graph.
# Removing edge (109, 112) with weight -1 from graph.
# Removing edge (117, 112) with weight -1 from graph.
# Removing edge (102, 112) with weight -1 from graph.
# Removing node 112 from graph.
# Adding edge (21, 122) with weight 2 to graph.
# Adding edge (26, 122) with weight 1 to graph.
# Adding edge (63, 122) with weight 1 to graph.
# Adding edge (96, 122) with weight -1 to graph.
# Adding edge (90, 122) with weight -2 to graph.
# Adding edge (68, 122) with weight -1 to graph.
# Adding edge (109, 122) with weight -2 to graph.
# Adding edge (117, 122) with weight -1 to graph.
# Adding edge (102, 122) with weight -3 to graph.
# Iter 43: Graph has 85 nodes and 315 edges remaining.
# QAOA Cost = -104.9653743428485. Anti-Correlating Edge (26, 116) that has maximum absolute weight -0.28318340750494536.
# Node 26 and 116 were contained in 2 and 19 triangles respectively.
# Removing edge (116, 26) with weight 2 from graph.
# Removing edge (77, 26) with weight 1 from graph.
# Removing edge (111, 26) with weight 1 from graph.
# Removing edge (118, 26) with weight 1 from graph.
# Removing edge (124, 26) with weight 1 from graph.
# Removing edge (121, 26) with weight 1 from graph.
# Removing edge (122, 26) with weight 1 from graph.
# Removing node 26 from graph.
# Adding edge (77, 116) with weight -1 to graph.
# Adding edge (111, 116) with weight -1 to graph.
# Adding edge (118, 116) with weight -1 to graph.
# Adding edge (124, 116) with weight -2 to graph.
# Adding edge (121, 116) with weight -1 to graph.
# Adding edge (122, 116) with weight -2 to graph.
# Iter 44: Graph has 84 nodes and 312 edges remaining.
# QAOA Cost = -97.44737765358504. Correlating Edge (119, 121) that has maximum absolute weight 0.27382764829431994.
# Node 119 and 121 were contained in 1 and 1 triangles respectively.
# Removing edge (121, 119) with weight -1 from graph.
# Removing edge (11, 119) with weight 1 from graph.
# Removing edge (103, 119) with weight -1 from graph.
# Removing edge (113, 119) with weight -1 from graph.
# Removing edge (126, 119) with weight -1 from graph.
# Removing edge (116, 119) with weight -1 from graph.
# Removing node 119 from graph.
# Adding edge (11, 121) with weight 1 to graph.
# Adding edge (103, 121) with weight -1 to graph.
# Adding edge (113, 121) with weight -1 to graph.
# Adding edge (126, 121) with weight -1 to graph.
# Adding edge (116, 121) with weight -2 to graph.
# Iter 45: Graph has 83 nodes and 310 edges remaining.
# QAOA Cost = -97.66005382008488. Anti-Correlating Edge (0, 105) that has maximum absolute weight -0.27285117868079656.
# Node 0 and 105 were contained in 3 and 2 triangles respectively.
# Removing edge (105, 0) with weight 1 from graph.
# Removing edge (73, 0) with weight 1 from graph.
# Removing edge (74, 0) with weight 1 from graph.
# Removing edge (78, 0) with weight 1 from graph.
# Removing edge (81, 0) with weight 1 from graph.
# Removing edge (127, 0) with weight 1 from graph.
# Removing edge (102, 0) with weight 1 from graph.
# Removing node 0 from graph.
# Adding edge (73, 105) with weight -1 to graph.
# Adding edge (74, 105) with weight -1 to graph.
# Adding edge (78, 105) with weight -1 to graph.
# Adding edge (81, 105) with weight -1 to graph.
# Adding edge (127, 105) with weight -1 to graph.
# Adding edge (102, 105) with weight -3 to graph.
# Iter 46: Graph has 82 nodes and 308 edges remaining.
# QAOA Cost = -90.8756280463678. Correlating Edge (102, 105) that has maximum absolute weight 0.3067252520894672.
# Node 102 and 105 were contained in 12 and 7 triangles respectively.
# Removing edge (105, 102) with weight -3 from graph.
# Removing edge (7, 102) with weight 1 from graph.
# Removing edge (20, 102) with weight 1 from graph.
# Removing edge (73, 102) with weight -2 from graph.
# Removing edge (86, 102) with weight -1 from graph.
# Removing edge (100, 102) with weight -2 from graph.
# Removing edge (101, 102) with weight -1 from graph.
# Removing edge (123, 102) with weight -1 from graph.
# Removing edge (65, 102) with weight -1 from graph.
# Removing edge (75, 102) with weight -1 from graph.
# Removing edge (89, 102) with weight -1 from graph.
# Removing edge (118, 102) with weight -1 from graph.
# Removing edge (116, 102) with weight -2 from graph.
# Removing edge (71, 102) with weight -1 from graph.
# Removing edge (103, 102) with weight -1 from graph.
# Removing edge (125, 102) with weight -1 from graph.
# Removing edge (90, 102) with weight -2 from graph.
# Removing edge (122, 102) with weight -3 from graph.
# Removing node 102 from graph.
# Adding edge (7, 105) with weight 1 to graph.
# Adding edge (20, 105) with weight 1 to graph.
# Adding edge (73, 105) with weight -3 to graph.
# Adding edge (86, 105) with weight -1 to graph.
# Adding edge (100, 105) with weight -2 to graph.
# Adding edge (101, 105) with weight -1 to graph.
# Adding edge (123, 105) with weight -1 to graph.
# Adding edge (65, 105) with weight -1 to graph.
# Adding edge (75, 105) with weight -1 to graph.
# Adding edge (89, 105) with weight -1 to graph.
# Adding edge (118, 105) with weight -1 to graph.
# Adding edge (116, 105) with weight -3 to graph.
# Adding edge (71, 105) with weight -1 to graph.
# Adding edge (103, 105) with weight -1 to graph.
# Adding edge (125, 105) with weight -1 to graph.
# Adding edge (90, 105) with weight -2 to graph.
# Adding edge (122, 105) with weight -3 to graph.
# Iter 47: Graph has 81 nodes and 305 edges remaining.
# QAOA Cost = -91.88307349630836. Correlating Edge (73, 105) that has maximum absolute weight 0.32803020573143626.
# Node 73 and 105 were contained in 2 and 34 triangles respectively.
# Removing edge (105, 73) with weight -3 from graph.
# Removing edge (3, 73) with weight 1 from graph.
# Removing edge (16, 73) with weight 1 from graph.
# Removing edge (17, 73) with weight 1 from graph.
# Removing edge (44, 73) with weight 1 from graph.
# Removing edge (63, 73) with weight 1 from graph.
# Removing edge (118, 73) with weight -1 from graph.
# Removing node 73 from graph.
# Adding edge (3, 105) with weight 1 to graph.
# Adding edge (16, 105) with weight 1 to graph.
# Adding edge (17, 105) with weight 1 to graph.
# Adding edge (44, 105) with weight 1 to graph.
# Adding edge (63, 105) with weight 1 to graph.
# Adding edge (118, 105) with weight -2 to graph.
# Iter 48: Graph has 80 nodes and 303 edges remaining.
# QAOA Cost = -92.98697096609052. Anti-Correlating Edge (10, 65) that has maximum absolute weight -0.29815618969744934.
# Node 10 and 65 were contained in 3 and 3 triangles respectively.
# Removing edge (65, 10) with weight 1 from graph.
# Removing edge (85, 10) with weight 1 from graph.
# Removing edge (89, 10) with weight 1 from graph.
# Removing edge (100, 10) with weight 1 from graph.
# Removing edge (105, 10) with weight 1 from graph.
# Removing node 10 from graph.
# Adding edge (85, 65) with weight -1 to graph.
# Adding edge (89, 65) with weight -1 to graph.
# Adding edge (100, 65) with weight -1 to graph.
# Adding edge (105, 65) with weight -2 to graph.
# Iter 49: Graph has 79 nodes and 301 edges remaining.
# QAOA Cost = -88.43045287342322. Correlating Edge (65, 100) that has maximum absolute weight 0.305738801081439.
# Node 65 and 100 were contained in 6 and 5 triangles respectively.
# Removing edge (100, 65) with weight -1 from graph.
# Removing edge (11, 65) with weight 1 from graph.
# Removing edge (13, 65) with weight 1 from graph.
# Removing edge (90, 65) with weight -1 from graph.
# Removing edge (105, 65) with weight -2 from graph.
# Removing edge (85, 65) with weight -1 from graph.
# Removing edge (89, 65) with weight -1 from graph.
# Removing node 65 from graph.
# Adding edge (11, 100) with weight 1 to graph.
# Adding edge (13, 100) with weight 2 to graph.
# Adding edge (90, 100) with weight -1 to graph.
# Adding edge (105, 100) with weight -4 to graph.
# Adding edge (85, 100) with weight -1 to graph.
# Adding edge (89, 100) with weight -1 to graph.
# Iter 50: Graph has 78 nodes and 298 edges remaining.
# QAOA Cost = -88.30641100304706. Anti-Correlating Edge (13, 100) that has maximum absolute weight -0.3371610344741318.
# Node 13 and 100 were contained in 7 and 8 triangles respectively.
# Removing edge (100, 13) with weight 2 from graph.
# Removing edge (64, 13) with weight 1 from graph.
# Removing edge (68, 13) with weight 1 from graph.
# Removing edge (78, 13) with weight 1 from graph.
# Removing edge (93, 13) with weight 1 from graph.
# Removing edge (105, 13) with weight 1 from graph.
# Removing edge (118, 13) with weight 1 from graph.
# Removing edge (122, 13) with weight 1 from graph.
# Removing node 13 from graph.
# Adding edge (64, 100) with weight -1 to graph.
# Adding edge (68, 100) with weight -2 to graph.
# Adding edge (78, 100) with weight -1 to graph.
# Adding edge (93, 100) with weight -1 to graph.
# Adding edge (105, 100) with weight -5 to graph.
# Adding edge (118, 100) with weight -1 to graph.
# Adding edge (122, 100) with weight -1 to graph.
# Iter 51: Graph has 77 nodes and 295 edges remaining.
# QAOA Cost = -79.51123717800354. Anti-Correlating Edge (21, 75) that has maximum absolute weight -0.2765454721656123.
# Node 21 and 75 were contained in 8 and 4 triangles respectively.
# Removing edge (75, 21) with weight 1 from graph.
# Removing edge (67, 21) with weight 1 from graph.
# Removing edge (74, 21) with weight 1 from graph.
# Removing edge (89, 21) with weight 1 from graph.
# Removing edge (103, 21) with weight 1 from graph.
# Removing edge (105, 21) with weight 1 from graph.
# Removing edge (120, 21) with weight 1 from graph.
# Removing edge (123, 21) with weight 1 from graph.
# Removing edge (122, 21) with weight 2 from graph.
# Removing node 21 from graph.
# Adding edge (67, 75) with weight -1 to graph.
# Adding edge (74, 75) with weight -1 to graph.
# Adding edge (89, 75) with weight -1 to graph.
# Adding edge (103, 75) with weight -1 to graph.
# Adding edge (105, 75) with weight -2 to graph.
# Adding edge (120, 75) with weight -1 to graph.
# Adding edge (123, 75) with weight -1 to graph.
# Adding edge (122, 75) with weight -3 to graph.
# Iter 52: Graph has 76 nodes and 292 edges remaining.
# QAOA Cost = -69.65382224945952. Correlating Edge (75, 122) that has maximum absolute weight 0.30684521343131616.
# Node 75 and 122 were contained in 9 and 33 triangles respectively.
# Removing edge (122, 75) with weight -3 from graph.
# Removing edge (5, 75) with weight 1 from graph.
# Removing edge (16, 75) with weight 1 from graph.
# Removing edge (57, 75) with weight 1 from graph.
# Removing edge (62, 75) with weight 1 from graph.
# Removing edge (105, 75) with weight -2 from graph.
# Removing edge (67, 75) with weight -1 from graph.
# Removing edge (74, 75) with weight -1 from graph.
# Removing edge (89, 75) with weight -1 from graph.
# Removing edge (103, 75) with weight -1 from graph.
# Removing edge (120, 75) with weight -1 from graph.
# Removing edge (123, 75) with weight -1 from graph.
# Removing node 75 from graph.
# Adding edge (5, 122) with weight 1 to graph.
# Adding edge (16, 122) with weight 1 to graph.
# Adding edge (57, 122) with weight 1 to graph.
# Adding edge (62, 122) with weight 1 to graph.
# Adding edge (105, 122) with weight -5 to graph.
# Adding edge (67, 122) with weight -1 to graph.
# Adding edge (74, 122) with weight -2 to graph.
# Adding edge (89, 122) with weight -1 to graph.
# Adding edge (103, 122) with weight -1 to graph.
# Adding edge (120, 122) with weight -1 to graph.
# Adding edge (123, 122) with weight -1 to graph.
# Iter 53: Graph has 75 nodes and 289 edges remaining.
# QAOA Cost = -70.22354842425963. Anti-Correlating Edge (24, 67) that has maximum absolute weight -0.2919111475018173.
# Node 24 and 67 were contained in 6 and 4 triangles respectively.
# Removing edge (67, 24) with weight 1 from graph.
# Removing edge (64, 24) with weight 1 from graph.
# Removing edge (71, 24) with weight 1 from graph.
# Removing edge (80, 24) with weight 1 from graph.
# Removing edge (83, 24) with weight 1 from graph.
# Removing edge (86, 24) with weight 1 from graph.
# Removing edge (87, 24) with weight 1 from graph.
# Removing edge (100, 24) with weight 1 from graph.
# Removing edge (123, 24) with weight 1 from graph.
# Removing edge (122, 24) with weight 1 from graph.
# Removing node 24 from graph.
# Adding edge (64, 67) with weight -1 to graph.
# Adding edge (71, 67) with weight -1 to graph.
# Adding edge (80, 67) with weight -1 to graph.
# Adding edge (83, 67) with weight -1 to graph.
# Adding edge (86, 67) with weight -1 to graph.
# Adding edge (87, 67) with weight -1 to graph.
# Adding edge (100, 67) with weight -2 to graph.
# Adding edge (123, 67) with weight -1 to graph.
# Adding edge (122, 67) with weight -2 to graph.
# Iter 54: Graph has 74 nodes and 286 edges remaining.
# QAOA Cost = -60.471515329358226. Anti-Correlating Edge (16, 117) that has maximum absolute weight -0.2860967241388581.
# Node 16 and 117 were contained in 3 and 2 triangles respectively.
# Removing edge (117, 16) with weight 1 from graph.
# Removing edge (81, 16) with weight 1 from graph.
# Removing edge (87, 16) with weight 1 from graph.
# Removing edge (105, 16) with weight 1 from graph.
# Removing edge (122, 16) with weight 1 from graph.
# Removing node 16 from graph.
# Adding edge (81, 117) with weight -1 to graph.
# Adding edge (87, 117) with weight -1 to graph.
# Adding edge (105, 117) with weight -1 to graph.
# Adding edge (122, 117) with weight -2 to graph.
# Iter 55: Graph has 73 nodes and 284 edges remaining.
# QAOA Cost = -55.836686855737774. Anti-Correlating Edge (20, 81) that has maximum absolute weight -0.2704719754261577.
# Node 20 and 81 were contained in 1 and 4 triangles respectively.
# Removing edge (81, 20) with weight 1 from graph.
# Removing edge (77, 20) with weight 1 from graph.
# Removing edge (82, 20) with weight 1 from graph.
# Removing edge (105, 20) with weight 1 from graph.
# Removing node 20 from graph.
# Adding edge (77, 81) with weight -1 to graph.
# Adding edge (82, 81) with weight -1 to graph.
# Adding edge (105, 81) with weight -2 to graph.
# Iter 56: Graph has 72 nodes and 282 edges remaining.
# QAOA Cost = -52.29807582576925. Anti-Correlating Edge (63, 77) that has maximum absolute weight -0.2765626534005253.
# Node 63 and 77 were contained in 10 and 3 triangles respectively.
# Removing edge (77, 63) with weight 1 from graph.
# Removing edge (81, 63) with weight 1 from graph.
# Removing edge (116, 63) with weight 1 from graph.
# Removing edge (120, 63) with weight 1 from graph.
# Removing edge (125, 63) with weight 1 from graph.
# Removing edge (118, 63) with weight 1 from graph.
# Removing edge (122, 63) with weight 1 from graph.
# Removing edge (105, 63) with weight 1 from graph.
# Removing node 63 from graph.
# Adding edge (81, 77) with weight -2 to graph.
# Adding edge (116, 77) with weight -2 to graph.
# Adding edge (120, 77) with weight -1 to graph.
# Adding edge (125, 77) with weight -1 to graph.
# Adding edge (118, 77) with weight -1 to graph.
# Adding edge (122, 77) with weight -1 to graph.
# ...
# Removing edge (28, 101) with weight 1 from graph.
# Removing edge (46, 101) with weight 1 from graph.
# Removing edge (84, 101) with weight -1 from graph.
# Removing edge (98, 101) with weight -1 from graph.
# Removing edge (113, 101) with weight -1 from graph.
# Removing node 101 from graph.
# Adding edge (9, 127) with weight 4 to graph.
# Adding edge (28, 127) with weight 5 to graph.
# Adding edge (46, 127) with weight 4 to graph.
# Adding edge (84, 127) with weight -3 to graph.
# Adding edge (98, 127) with weight -4 to graph.
# Adding edge (113, 127) with weight -1 to graph.
# Iter 96: Graph has 32 nodes and 84 edges remaining.
# QAOA Cost = -34.278516123599324. Anti-Correlating Edge (9, 98) that has maximum absolute weight -0.4752786210186365.
# Node 9 and 98 were contained in 3 and 6 triangles respectively.
# Removing edge (98, 9) with weight 1 from graph.
# Removing edge (72, 9) with weight 1 from graph.
# Removing edge (95, 9) with weight 1 from graph.
# Removing edge (127, 9) with weight 4 from graph.
# Removing node 9 from graph.
# Adding edge (72, 98) with weight -1 to graph.
# Adding edge (95, 98) with weight -1 to graph.
# Adding edge (127, 98) with weight -8 to graph.
# Iter 97: Graph has 31 nodes and 82 edges remaining.
# QAOA Cost = -24.399338366127335. Anti-Correlating Edge (28, 98) that has maximum absolute weight -0.4512987219307292.
# Node 28 and 98 were contained in 8 and 11 triangles respectively.
# Removing edge (98, 28) with weight 1 from graph.
# Removing edge (72, 28) with weight 1 from graph.
# Removing edge (76, 28) with weight 1 from graph.
# Removing edge (95, 28) with weight 1 from graph.
# Removing edge (113, 28) with weight 1 from graph.
# Removing edge (120, 28) with weight 1 from graph.
# Removing edge (127, 28) with weight 5 from graph.
# Removing node 28 from graph.
# Adding edge (72, 98) with weight -2 to graph.
# Adding edge (76, 98) with weight -1 to graph.
# Adding edge (95, 98) with weight -2 to graph.
# Adding edge (113, 98) with weight -1 to graph.
# Adding edge (120, 98) with weight -1 to graph.
# Adding edge (127, 98) with weight -13 to graph.
# Iter 98: Graph has 30 nodes and 78 edges remaining.
# QAOA Cost = -9.14814417875839. Correlating Edge (98, 127) that has maximum absolute weight 0.5651806529997373.
# Node 98 and 127 were contained in 12 and 49 triangles respectively.
# Removing edge (127, 98) with weight -13 from graph.
# Removing edge (25, 98) with weight 1 from graph.
# Removing edge (32, 98) with weight 1 from graph.
# Removing edge (46, 98) with weight 1 from graph.
# Removing edge (59, 98) with weight 1 from graph.
# Removing edge (72, 98) with weight -2 from graph.
# Removing edge (95, 98) with weight -2 from graph.
# Removing edge (76, 98) with weight -1 from graph.
# Removing edge (113, 98) with weight -1 from graph.
# Removing edge (120, 98) with weight -1 from graph.
# Removing node 98 from graph.
# Adding edge (25, 127) with weight 4 to graph.
# Adding edge (32, 127) with weight 3 to graph.
# Adding edge (46, 127) with weight 5 to graph.
# Adding edge (59, 127) with weight 3 to graph.
# Adding edge (72, 127) with weight -5 to graph.
# Adding edge (95, 127) with weight -3 to graph.
# Adding edge (76, 127) with weight -2 to graph.
# Adding edge (113, 127) with weight -2 to graph.
# Adding edge (120, 127) with weight -4 to graph.
# Iter 99: Graph has 29 nodes and 68 edges remaining.
# QAOA Cost = -22.530421819018557. Anti-Correlating Edge (46, 72) that has maximum absolute weight -0.5376689316568158.
# Node 46 and 72 were contained in 4 and 3 triangles respectively.
# Removing edge (72, 46) with weight 1 from graph.
# Removing edge (76, 46) with weight 1 from graph.
# Removing edge (111, 46) with weight 1 from graph.
# Removing edge (121, 46) with weight 1 from graph.
# Removing edge (127, 46) with weight 5 from graph.
# Removing node 46 from graph.
# Adding edge (76, 72) with weight -1 to graph.
# Adding edge (111, 72) with weight -1 to graph.
# Adding edge (121, 72) with weight -1 to graph.
# Adding edge (127, 72) with weight -10 to graph.
# Iter 100: Graph has 28 nodes and 66 edges remaining.
# QAOA Cost = -8.111312880606416. Correlating Edge (72, 127) that has maximum absolute weight 0.49428268454799756.
# Node 72 and 127 were contained in 6 and 39 triangles respectively.
# Removing edge (127, 72) with weight -10 from graph.
# Removing edge (19, 72) with weight 1 from graph.
# Removing edge (40, 72) with weight 1 from graph.
# Removing edge (76, 72) with weight -1 from graph.
# Removing edge (111, 72) with weight -1 from graph.
# Removing edge (121, 72) with weight -1 from graph.
# Removing node 72 from graph.
# Adding edge (19, 127) with weight 4 to graph.
# Adding edge (40, 127) with weight 4 to graph.
# Adding edge (76, 127) with weight -3 to graph.
# Adding edge (111, 127) with weight -2 to graph.
# Adding edge (121, 127) with weight -6 to graph.
# Iter 101: Graph has 27 nodes and 60 edges remaining.
# QAOA Cost = -17.106000808831872. Anti-Correlating Edge (19, 76) that has maximum absolute weight -0.4898671814311566.
# Node 19 and 76 were contained in 2 and 2 triangles respectively.
# Removing edge (76, 19) with weight 1 from graph.
# Removing edge (103, 19) with weight 1 from graph.
# Removing edge (127, 19) with weight 4 from graph.
# Removing node 19 from graph.
# Adding edge (103, 76) with weight -1 to graph.
# Adding edge (127, 76) with weight -7 to graph.
# Iter 102: Graph has 26 nodes and 58 edges remaining.
# QAOA Cost = -10.23463531879493. Correlating Edge (76, 127) that has maximum absolute weight 0.468539059533286.
# Node 76 and 127 were contained in 2 and 33 triangles respectively.
# Removing edge (127, 76) with weight -7 from graph.
# Removing edge (51, 76) with weight 1 from graph.
# Removing edge (103, 76) with weight -1 from graph.
# Removing node 76 from graph.
# Adding edge (51, 127) with weight 3 to graph.
# Adding edge (103, 127) with weight -4 to graph.
# Iter 103: Graph has 25 nodes and 55 edges remaining.
# QAOA Cost = -13.933459506570497. Correlating Edge (103, 121) that has maximum absolute weight 0.49833750344532024.
# Node 103 and 121 were contained in 2 and 5 triangles respectively.
# Removing edge (121, 103) with weight -1 from graph.
# Removing edge (32, 103) with weight 1 from graph.
# Removing edge (127, 103) with weight -4 from graph.
# Removing node 103 from graph.
# Adding edge (32, 121) with weight 1 to graph.
# Adding edge (127, 121) with weight -10 to graph.
# Iter 104: Graph has 24 nodes and 53 edges remaining.
# QAOA Cost = -9.563781109584015. Correlating Edge (121, 127) that has maximum absolute weight 0.5089861236471299.
# Node 121 and 127 were contained in 5 and 30 triangles respectively.
# Removing edge (127, 121) with weight -10 from graph.
# Removing edge (82, 121) with weight -1 from graph.
# Removing edge (125, 121) with weight -1 from graph.
# Removing edge (113, 121) with weight -1 from graph.
# Removing edge (126, 121) with weight -1 from graph.
# Removing edge (32, 121) with weight 1 from graph.
# Removing node 121 from graph.
# Adding edge (82, 127) with weight -4 to graph.
# Adding edge (125, 127) with weight -4 to graph.
# Adding edge (113, 127) with weight -3 to graph.
# Adding edge (126, 127) with weight -3 to graph.
# Adding edge (32, 127) with weight 4 to graph.
# Iter 105: Graph has 23 nodes and 47 edges remaining.
# QAOA Cost = -17.93268032038215. Anti-Correlating Edge (25, 82) that has maximum absolute weight -0.5211150237445119.
# Node 25 and 82 were contained in 3 and 2 triangles respectively.
# Removing edge (82, 25) with weight 1 from graph.
# Removing edge (93, 25) with weight 1 from graph.
# Removing edge (125, 25) with weight 1 from graph.
# Removing edge (127, 25) with weight 4 from graph.
# Removing node 25 from graph.
# Adding edge (93, 82) with weight -1 to graph.
# Adding edge (125, 82) with weight -1 to graph.
# Adding edge (127, 82) with weight -8 to graph.
# Iter 106: Graph has 22 nodes and 45 edges remaining.
# QAOA Cost = -8.864825531290302. Correlating Edge (82, 127) that has maximum absolute weight 0.4744155119612187.
# Node 82 and 127 were contained in 4 and 24 triangles respectively.
# Removing edge (127, 82) with weight -8 from graph.
# Removing edge (51, 82) with weight 1 from graph.
# Removing edge (93, 82) with weight -1 from graph.
# Removing edge (125, 82) with weight -1 from graph.
# Removing node 82 from graph.
# Adding edge (51, 127) with weight 4 to graph.
# Adding edge (93, 127) with weight -3 to graph.
# Adding edge (125, 127) with weight -5 to graph.
# Iter 107: Graph has 21 nodes and 41 edges remaining.
# QAOA Cost = -14.011673790102106. Anti-Correlating Edge (51, 120) that has maximum absolute weight -0.5328512026447318.
# Node 51 and 120 were contained in 3 and 1 triangles respectively.
# Removing edge (120, 51) with weight 1 from graph.
# Removing edge (84, 51) with weight 1 from graph.
# Removing edge (125, 51) with weight 1 from graph.
# Removing edge (127, 51) with weight 4 from graph.
# Removing node 51 from graph.
# Adding edge (84, 120) with weight -1 to graph.
# Adding edge (125, 120) with weight -1 to graph.
# Adding edge (127, 120) with weight -8 to graph.
# Iter 108: Graph has 20 nodes and 39 edges remaining.
# QAOA Cost = -5.315545743767614. Correlating Edge (120, 125) that has maximum absolute weight 0.5057584371915019.
# Node 120 and 125 were contained in 2 and 2 triangles respectively.
# Removing edge (125, 120) with weight -1 from graph.
# Removing edge (127, 120) with weight -8 from graph.
# Removing edge (84, 120) with weight -1 from graph.
# Removing node 120 from graph.
# Adding edge (127, 125) with weight -13 to graph.
# Adding edge (84, 125) with weight -1 to graph.
# Iter 109: Graph has 19 nodes and 37 edges remaining.
# QAOA Cost = -3.2591159325137022. Correlating Edge (125, 127) that has maximum absolute weight 0.6378809550114074.
# Node 125 and 127 were contained in 2 and 19 triangles respectively.
# Removing edge (127, 125) with weight -13 from graph.
# Removing edge (5, 125) with weight 1 from graph.
# Removing edge (84, 125) with weight -1 from graph.
# Removing node 125 from graph.
# Adding edge (5, 127) with weight 3 to graph.
# Adding edge (84, 127) with weight -4 to graph.
# Iter 110: Graph has 18 nodes and 34 edges remaining.
# QAOA Cost = -11.593145445211364. Anti-Correlating Edge (40, 93) that has maximum absolute weight -0.4976943977519257.
# Node 40 and 93 were contained in 2 and 1 triangles respectively.
# Removing edge (93, 40) with weight 1 from graph.
# Removing edge (86, 40) with weight 1 from graph.
# Removing edge (127, 40) with weight 4 from graph.
# Removing node 40 from graph.
# Adding edge (86, 93) with weight -1 to graph.
# Adding edge (127, 93) with weight -7 to graph.
# Iter 111: Graph has 17 nodes and 32 edges remaining.
# QAOA Cost = -5.2582507053688055. Correlating Edge (93, 127) that has maximum absolute weight 0.48690625535448673.
# Node 93 and 127 were contained in 1 and 16 triangles respectively.
# Removing edge (127, 93) with weight -7 from graph.
# Removing edge (86, 93) with weight -1 from graph.
# Removing node 93 from graph.
# Adding edge (86, 127) with weight -3 to graph.
# Iter 112: Graph has 16 nodes and 30 edges remaining.
# QAOA Cost = -8.220357936583426. Anti-Correlating Edge (32, 110) that has maximum absolute weight -0.4857136427754496.
# Node 32 and 110 were contained in 5 and 4 triangles respectively.
# Removing edge (110, 32) with weight 1 from graph.
# Removing edge (86, 32) with weight 1 from graph.
# Removing edge (88, 32) with weight 1 from graph.
# Removing edge (95, 32) with weight 1 from graph.
# Removing edge (127, 32) with weight 4 from graph.
# Removing node 32 from graph.
# Adding edge (86, 110) with weight -2 to graph.
# Adding edge (88, 110) with weight -1 to graph.
# Adding edge (95, 110) with weight -1 to graph.
# Adding edge (127, 110) with weight -10 to graph.
# Iter 113: Graph has 15 nodes and 27 edges remaining.
# QAOA Cost = 1.313886607478169. Correlating Edge (110, 127) that has maximum absolute weight 0.62246814772784.
# Node 110 and 127 were contained in 4 and 13 triangles respectively.
# Removing edge (127, 110) with weight -10 from graph.
# Removing edge (86, 110) with weight -2 from graph.
# Removing edge (5, 110) with weight 1 from graph.
# Removing edge (88, 110) with weight -1 from graph.
# Removing edge (95, 110) with weight -1 from graph.
# Removing node 110 from graph.
# Adding edge (86, 127) with weight -5 to graph.
# Adding edge (5, 127) with weight 4 to graph.
# Adding edge (88, 127) with weight -4 to graph.
# Adding edge (95, 127) with weight -4 to graph.
# Iter 114: Graph has 14 nodes and 22 edges remaining.
# QAOA Cost = -4.931636036064605. Anti-Correlating Edge (5, 113) that has maximum absolute weight -0.5177646442303742.
# Node 5 and 113 were contained in 2 and 2 triangles respectively.
# Removing edge (113, 5) with weight 1 from graph.
# Removing edge (126, 5) with weight 1 from graph.
# Removing edge (127, 5) with weight 4 from graph.
# Removing node 5 from graph.
# Adding edge (126, 113) with weight -1 to graph.
# Adding edge (127, 113) with weight -7 to graph.
# Iter 115: Graph has 13 nodes and 20 edges remaining.
# QAOA Cost = 2.07256211180478. Correlating Edge (113, 127) that has maximum absolute weight 0.4908847972421449.
# Node 113 and 127 were contained in 2 and 8 triangles respectively.
# Removing edge (127, 113) with weight -7 from graph.
# Removing edge (42, 113) with weight 1 from graph.
# Removing edge (126, 113) with weight -1 from graph.
# Removing node 113 from graph.
# Adding edge (42, 127) with weight 3 to graph.
# Adding edge (126, 127) with weight -4 to graph.
# Iter 116: Graph has 12 nodes and 17 edges remaining.
# QAOA Cost = -1.5282811807816512. Anti-Correlating Edge (42, 84) that has maximum absolute weight -0.5088423879039837.
# Node 42 and 84 were contained in 2 and 2 triangles respectively.
# Removing edge (84, 42) with weight 1 from graph.
# Removing edge (80, 42) with weight 1 from graph.
# Removing edge (127, 42) with weight 3 from graph.
# Removing node 42 from graph.
# Adding edge (80, 84) with weight -1 to graph.
# Adding edge (127, 84) with weight -7 to graph.
# Iter 117: Graph has 11 nodes and 15 edges remaining.
# QAOA Cost = 4.170897795199774. Correlating Edge (84, 127) that has maximum absolute weight 0.4972852084314856.
# Node 84 and 127 were contained in 3 and 5 triangles respectively.
# Removing edge (127, 84) with weight -7 from graph.
# Removing edge (45, 84) with weight 1 from graph.
# Removing edge (80, 84) with weight -1 from graph.
# Removing node 84 from graph.
# Adding edge (45, 127) with weight 3 to graph.
# Adding edge (80, 127) with weight -3 to graph.
# Iter 118: Graph has 10 nodes and 12 edges remaining.
# QAOA Cost = 0.8078544006180375. Anti-Correlating Edge (45, 95) that has maximum absolute weight -0.5015393283414369.
# Node 45 and 95 were contained in 3 and 1 triangles respectively.
# Removing edge (95, 45) with weight 1 from graph.
# Removing edge (80, 45) with weight 1 from graph.
# Removing edge (126, 45) with weight 1 from graph.
# Removing edge (127, 45) with weight 3 from graph.
# Removing node 45 from graph.
# Adding edge (80, 95) with weight -1 to graph.
# Adding edge (126, 95) with weight -1 to graph.
# Adding edge (127, 95) with weight -7 to graph.
# Iter 119: Graph has 9 nodes and 10 edges remaining.
# QAOA Cost = 7.130170769509243. Correlating Edge (95, 127) that has maximum absolute weight 0.5168545349151157.
# Node 95 and 127 were contained in 2 and 2 triangles respectively.
# Removing edge (127, 95) with weight -7 from graph.
# Removing edge (80, 95) with weight -1 from graph.
# Removing edge (126, 95) with weight -1 from graph.
# Removing node 95 from graph.
# Adding edge (80, 127) with weight -4 to graph.
# Adding edge (126, 127) with weight -5 to graph.
# Iter 120: Graph has 8 nodes and 7 edges remaining.
# QAOA Cost = 4.246175079187093. Correlating Edge (86, 127) that has maximum absolute weight 0.4999999999999999.
# Node 86 and 127 were contained in 0 and 0 triangles respectively.
# Removing edge (127, 86) with weight -5 from graph.
# Removing node 86 from graph.
#
# Brute-Forcing
# Best reduced cost found so far is 0.0 for assignment [1, 1, 1, 1, 1, 1, 1].
# Best reduced cost found so far is 1.0 for assignment [1, -1, -1, 1, -1, -1, -1].
# Best reduced cost found so far is 3.0 for assignment [1, -1, -1, -1, -1, -1, -1].
# Best Cost found for the original problem is 384.0.
